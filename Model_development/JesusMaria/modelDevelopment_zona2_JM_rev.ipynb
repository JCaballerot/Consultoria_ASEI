# %% [markdown]
# <a href="https://colab.research.google.com/github/JCaballerot/Consultoria_ASEI/blob/main/Model_development/JesusMaria/modelDevelopment_zona2_JM_rev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 align=center><font size = 5>Forecasting Jesus Maria Zona 2
# </font></h1>
#
# ---

# %% [markdown]
# # Librerias

# %% [markdown]
# Cargamos las librerías que utilizaremos en el proyecto

# %%
import pandas as pd

import warnings                                  
warnings.filterwarnings('ignore')

import numpy as np                               
import pandas as pd                              
import matplotlib.pyplot as plt                  
import seaborn as sns                            

from sklearn.metrics import *

# %%
def plotMovingAverage(series, window, plot_intervals=False, scale=1.96, plot_anomalies=False):

    """
        series - dataframe with timeseries
        window - rolling window size 
        plot_intervals - show confidence intervals
        plot_anomalies - show anomalies 

    """
    rolling_mean = series.rolling(window=window).mean()

    plt.figure(figsize=(15,5))
    plt.title("Moving average\n window size = {}".format(window))
    plt.plot(rolling_mean, "g", label="Rolling mean trend",  color='red')

    # Plot confidence intervals for smoothed values
    if plot_intervals:
        mae = mean_absolute_error(series[window:], rolling_mean[window:])
        deviation = np.std(series[window:] - rolling_mean[window:])
        lower_bond = rolling_mean - (mae + scale * deviation)
        upper_bond = rolling_mean + (mae + scale * deviation)
        plt.plot(upper_bond, "r--", label="Upper Bond / Lower Bond")
        plt.plot(lower_bond, "r--")
        
        # Having the intervals, find abnormal values
        if plot_anomalies:
            anomalies = pd.DataFrame(index=series.index, columns=series.columns)
            anomalies[series<lower_bond] = series[series<lower_bond]
            anomalies[series>upper_bond] = series[series>upper_bond]
            plt.plot(anomalies, "ro", markersize=10)
        
    plt.plot(series[window:], label="Actual values")
    plt.legend(loc="upper left")
    plt.grid(True)
    plt.xticks(rotation=90)

# %% [markdown]
# # Data

# %% [markdown]
# Importamos la información desde un archivo csv cargado en el file temporal y nos quedamos con los datos de la zona 2

# %%
target = 'Venta_zona_2'

pddf = pd.read_csv('datos_jesusmaria.csv',delimiter=';', index_col=['codmes'], parse_dates=['codmes']).fillna(0)
pddf = pddf[[target]]

pddf[target+'_lag2'] = pddf[target].shift(2)
pddf[target+'_lag3'] = pddf[target].shift(3)

# %%
macro = pd.read_csv('macros_corregido.csv', index_col=['codmes'], parse_dates=['codmes']).drop(columns=['imp_mater_const'])
variables_macro = macro.columns.tolist()
macro[variables_macro] = macro[variables_macro].shift(3)

# %%
asei = pd.read_csv('variables_asei_new.csv', delimiter = ';', index_col=['codmes'], parse_dates=['codmes'])
variables_asei = asei.columns.tolist()
asei[variables_asei] = asei[variables_asei].shift(2)

# %%
pddf2 = pd.merge(pddf, macro, on = 'codmes', how='left').copy()
pddf2 = pd.merge(pddf2, asei, on = 'codmes', how='left')

variables = variables_macro + variables_asei + [target+'_lag2', target+'_lag3']

# %%
pddfRes = pddf2.copy()

pddfRes[[x + '_avg3' for x in variables]] = pddfRes[variables].rolling(3, min_periods = 3).mean()
pddfRes[[x + '_avg6' for x in variables]] = pddfRes[variables].rolling(6, min_periods = 6).mean()

pddfRes = pddfRes.iloc[8:]

# %%
for x in variables:
  pddfRes[x + '_rat3to6'] = pddfRes[x + '_avg3']/pddfRes[x + '_avg6']

# %%
variables_f = variables_macro +\
              variables_asei +\
              [target+'_lag2', target+'_lag3'] +\
              [x + '_avg3' for x in variables] +\
              [x + '_avg6' for x in variables] +\
              [x + '_rat3to6' for x in variables]

# %%
pddfRes['intercept'] = 1

# %%
test_size = 2

data = pddfRes.copy().dropna()
X_train = pddfRes[:-test_size].dropna()
X_test  = pddfRes[-test_size:].dropna()

# %%
# Estandarización

X_train[[x + '_std' for x in variables_f]] = (X_train[variables_f] - X_train[variables_f].mean())/X_train[variables_f].std()
X_test[[x + '_std'  for x in variables_f]] = (X_test[variables_f]  - X_train[variables_f].mean())/X_train[variables_f].std()
data[[x + '_std'    for x in variables_f]] = (data[variables_f]    - X_train[variables_f].mean())/X_train[variables_f].std()

# %%
X_train[['var_porc_demanda_interna_avg3', 'flg_feia_avg3', 'exp_PBI_avg3']].mean()
# Out:
# var_porc_demanda_interna_avg3    3.355473
# flg_feia_avg3                    0.340580
# exp_PBI_avg3                     0.045371
# dtype: float64

# %%
X_train[['var_porc_demanda_interna_avg3', 'flg_feia_avg3', 'exp_PBI_avg3']].std()
# Out:
# var_porc_demanda_interna_avg3    13.253201
# flg_feia_avg3                     0.192311
# exp_PBI_avg3                      0.016536
# dtype: float64

# %% [markdown]
# # Forecasting

# %% [markdown]
# ### Exploracion

# %% [markdown]
# Muestreamos la data en train y test bajo metodología OOT

# %%
plotMovingAverage(data[target], 6)

# %%
plotMovingAverage(data[target], 6, plot_intervals=True, scale=1.64, plot_anomalies=False)

# %%
from statsmodels.tsa.stattools import adfuller
from numpy import log

result = adfuller(X_train[target].dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])

# %% [markdown]
# Dado que el valor p es mayor que el nivel de significancia (0,05), diferenciemos las series y veamos cómo se ve el gráfico de autocorrelación.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':120})


# Original Series
fig, axes = plt.subplots(3, 2, sharex=True)
axes[0, 0].plot(X_train[target]); axes[0, 0].set_title('Original Series')
plot_acf(X_train[target], ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(X_train[target].diff()); axes[1, 0].set_title('1st Order Differencing')
plot_acf(X_train[target].diff().dropna(), ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot(X_train[target].diff().diff()); axes[2, 0].set_title('2nd Order Differencing')
plot_acf(X_train[target].diff().diff().dropna(), ax=axes[2, 1])

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Por los datos anteriores, podemos ver que la serie de tiempo alcanza la estacionariedad con dos órdenes de diferenciación.

# %%
# PACF plot of 1st differenced series
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=True)
axes[0].plot(X_train[target].diff()); axes[0].set_title('1st Differencing')
axes[1].set(ylim=(0,5))
plot_pacf(X_train[target].diff().dropna(), ax=axes[1])

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Podemos ver que el retraso 1 de PACF es bastante significativo ya que está muy por encima de la línea de significancia. Entonces, fijaremos el valor de p como 1.

# %% [markdown]
# ### MA (q)

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=True)
axes[0].plot(X_train[target].diff()); axes[0].set_title('1st Differencing')
axes[1].set(ylim=(0,1.2))
plot_acf(X_train[target].diff().dropna(), ax=axes[1])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Podemos ver que un 1 retraso están muy por encima de la línea de significación. Entonces, fijaremos q como 1. Si hay alguna duda, iremos con el modelo más simple que explica suficientemente la Y

# %% [markdown]
# ### Arima

# %% [markdown]
# Ahora, hemos determinado los valores de p, d y q. Disponemos de todo lo necesario para adaptarse al modelo ARIMA. Usaremos la implementación ARIMA() en el paquete statsmodels.
# (p,d,q)

# %%
# Plot
fig, axes = plt.subplots(2, 1, figsize=(10,5), dpi=100, sharex=True)

# Usual Differencing
axes[0].plot(X_train[target], label='Original Series')
axes[0].plot(X_train[target].diff(1), label='Usual Differencing')
axes[0].set_title('Usual Differencing')
axes[0].legend(loc='upper left', fontsize=10)


# Seasonal Differencing
axes[1].plot(X_train[target], label='Original Series')
axes[1].plot(X_train[target].diff(12), label='Seasonal Differencing', color='green')
axes[1].set_title('Seasonal Differencing')
plt.legend(loc='upper left', fontsize=10)
plt.suptitle('Ventas Zona 3', fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
from statsmodels.tsa.arima_model import ARIMA

features = [target + '_lag2_avg3']

# 2,1,1 ARIMA Model
model = ARIMA(endog = X_train[target], 
              exog = X_train[features],  
              order=(3,2,1))

model_fit = model.fit()
print(model_fit.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D2.Venta_zona_2   No. Observations:                   44
# Model:                 ARIMA(3, 2, 1)   Log Likelihood                -167.138
# Method:                       css-mle   S.D. of innovations             10.270
# Date:                Mon, 25 Jul 2022   AIC                            348.276
# Time:                        07:53:22   BIC                            360.765
# Sample:                             2   HQIC                           352.907
#
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      0.3422      0.617      0.555      0.582      -0.866       1.551
# Venta_zona_2_lag2_avg3    -0.0085      0.016     -0.541      0.592      -0.039       0.022
# ar.L1.D2.Venta_zona_2     -0.0313      0.151     -0.207      0.837      -0.328       0.265
# ar.L2.D2.Venta_zona_2     -0.1906      0.149     -1.276      0.210      -0.483       0.102
# ar.L3.D2.Venta_zona_2     -0.0977      0.155     -0.631      0.532      -0.401       0.206
# ma.L1.D2.Venta_zona_2     -1.0000      0.062    -16.005      0.000      -1.122      -0.878
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.5192           -1.7761j            1.8504           -0.2047
# AR.2            0.5192           +1.7761j            1.8504            0.2047
# AR.3           -2.9886           -0.0000j            2.9886           -0.5000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------

# %%
import pickle
pickle.dump(model_fit, open("./arima_jmz2.ml", 'wb'))

# %%
fc, se, conf  = model_fit.forecast(test_size, exog = X_test[features], alpha=0.05)
model_res = model_fit.predict(start = X_train.index[2], 
                                end = X_train.index[-1], dynamic=False, typ = 'levels')

data_res = data.copy()
data_res['venta_predicted'] = model_res
data_res.iloc[-test_size:]['venta_predicted'] = fc

sns.lineplot(data = data_res[[target, 'venta_predicted']])

# %%
# Plot residual errors
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %% [markdown]
# Los errores residuales parecen correctos con una media cercana a cero y una varianza uniforme. Grafiquemos los valores reales contra los valores ajustados usando plot_predict().

# %%
pd.set_option('display.max_rows', 500)

# %%
data_res[['venta_predicted',target]]

# %%
data_res[['venta_predicted',target]].to_csv('results_JM_zona2.csv', index=0)

# %%
data = data_res.copy().dropna()
X_train = data_res[:-test_size].dropna()
X_test  = data_res[-test_size:].dropna()

# %%
X_test[['venta_predicted', target]]

# %%
X_test[['venta_predicted', target]].corr()**2
# Out:
#                  venta_predicted  Venta_zona_2
# venta_predicted              1.0           1.0
# Venta_zona_2                 1.0           1.0

# %% [markdown]
# # Regresión

# %%
correlations = pd.DataFrame()

for col in variables_f:
  data_temp = X_train[[target, col]]
  correlation = data_temp[col].corr(data_temp[target])
  temp = pd.DataFrame({'target': [target],'variable': [col], 'correlacion' : [correlation]})
  correlations = correlations.append(temp)

correlations['correlacion_abs'] = correlations.correlacion.apply(lambda x: abs(x))
correlations['r2'] = correlations.correlacion.apply(lambda x: x**2)

correlations.sort_values(by = 'correlacion_abs', ascending = False, inplace = True)

# %%
correlations.head(50)
# Out:
#          target                                  variable  correlacion  \
# 0  Venta_zona_2                              ind_prec_alt     0.862470
# 0  Venta_zona_2                          tasa_interes_act    -0.855182
# 0  Venta_zona_2                         ind_prec_12_distr     0.854770
# 0  Venta_zona_2                         ind_prec_alt_avg3     0.848994
# 0  Venta_zona_2                     tasa_interes_act_avg3    -0.848989
# 0  Venta_zona_2                    ind_prec_12_distr_avg3     0.843709
# 0  Venta_zona_2                       tip_camb_banc_venta     0.839418
# 0  Venta_zona_2                     tasa_interes_act_avg6    -0.836966
# 0  Venta_zona_2                    precio_venta_zon1_avg6     0.823478
# 0  Venta_zona_2                  tip_camb_banc_venta_avg3     0.823446
# 0  Venta_zona_2                         ind_prec_alt_avg6     0.820192
# 0  Venta_zona_2                         ind_prec_med_avg3     0.817482
# 0  Venta_zona_2                    ind_prec_12_distr_avg6     0.817058
# 0  Venta_zona_2                              ind_prec_med     0.816347
# 0  Venta_zona_2                   precio_oferta_zon1_avg3     0.813001
# 0  Venta_zona_2                   precio_oferta_zon2_avg3     0.807889
# 0  Venta_zona_2                   precio_oferta_zon1_avg6     0.804642
# 0  Venta_zona_2                   precio_oferta_zon2_avg6     0.804145
# 0  Venta_zona_2                         ind_prec_med_avg6     0.802210
# 0  Venta_zona_2                  tip_camb_banc_venta_avg6     0.791292
# 0  Venta_zona_2                        precio_oferta_zon2     0.790178
# 0  Venta_zona_2                    precio_venta_zon3_avg6     0.785797
# 0  Venta_zona_2                  precio_oferta_total_avg6     0.785529
# 0  Venta_zona_2                  precio_oferta_total_avg3     0.784160
# 0  Venta_zona_2                        precio_oferta_zon1     0.779032
# 0  Venta_zona_2          ind_prec_cons_lima_met_alim_ener     0.769214
# 0  Venta_zona_2                    precio_venta_zon1_avg3     0.767363
# 0  Venta_zona_2     ind_prec_cons_lima_met_alim_ener_avg6     0.766689
# 0  Venta_zona_2                       precio_oferta_total     0.766329
# 0  Venta_zona_2     ind_prec_cons_lima_met_alim_ener_avg3     0.765743
# 0  Venta_zona_2               tip_camb_banc_venta_rat3to6     0.762162
# 0  Venta_zona_2                ind_tipo_camb_var_mes_avg6     0.756461
# 0  Venta_zona_2                   precio_oferta_zon3_avg6     0.755963
# 0  Venta_zona_2                   precio_oferta_zon3_avg3     0.750783
# 0  Venta_zona_2                        precio_oferta_zon3     0.750447
# 0  Venta_zona_2                          ind_preci_import     0.723737
# 0  Venta_zona_2                    precio_venta_zon3_avg3     0.711637
# 0  Venta_zona_2                  ind_preci_import_rat3to6     0.710822
# 0  Venta_zona_2                     ind_preci_import_avg3     0.707508
# 0  Venta_zona_2                    precio_venta_zon2_avg6     0.707330
# 0  Venta_zona_2                   precio_venta_total_avg6     0.699368
# 0  Venta_zona_2                         Venta_zona_2_lag2     0.685684
# 0  Venta_zona_2                     ind_preci_import_avg6     0.679437
# 0  Venta_zona_2                    Venta_zona_2_lag2_avg6     0.662615
# 0  Venta_zona_2                    precio_venta_zon2_avg3     0.658808
# 0  Venta_zona_2                         ind_prec_inm_avg6     0.658075
# 0  Venta_zona_2  ind_prec_cons_lima_met_alim_ener_rat3to6     0.650502
# 0  Venta_zona_2                    Venta_zona_2_lag2_avg3     0.645602
# 0  Venta_zona_2                    Venta_zona_2_lag3_avg6     0.637623
# 0  Venta_zona_2                   precio_venta_total_avg3     0.637145
#
#    correlacion_abs        r2
# 0         0.862470  0.743854
# 0         0.855182  0.731337
# 0         0.854770  0.730631
# 0         0.848994  0.720791
# 0         0.848989  0.720782
# 0         0.843709  0.711846
# 0         0.839418  0.704623
# 0         0.836966  0.700512
# 0         0.823478  0.678116
# 0         0.823446  0.678063
# 0         0.820192  0.672715
# 0         0.817482  0.668277
# 0         0.817058  0.667584
# 0         0.816347  0.666423
# 0         0.813001  0.660971
# 0         0.807889  0.652684
# 0         0.804642  0.647448
# 0         0.804145  0.646649
# 0         0.802210  0.643540
# 0         0.791292  0.626144
# 0         0.790178  0.624381
# 0         0.785797  0.617476
# 0         0.785529  0.617056
# 0         0.784160  0.614908
# 0         0.779032  0.606891
# 0         0.769214  0.591691
# 0         0.767363  0.588846
# 0         0.766689  0.587812
# 0         0.766329  0.587259
# 0         0.765743  0.586362
# 0         0.762162  0.580891
# 0         0.756461  0.572233
# 0         0.755963  0.571480
# 0         0.750783  0.563674
# 0         0.750447  0.563171
# 0         0.723737  0.523796
# 0         0.711637  0.506427
# 0         0.710822  0.505268
# 0         0.707508  0.500568
# 0         0.707330  0.500315
# 0         0.699368  0.489116
# 0         0.685684  0.470162
# 0         0.679437  0.461634
# 0         0.662615  0.439059
# 0         0.658808  0.434028
# 0         0.658075  0.433062
# 0         0.650502  0.423153
# 0         0.645602  0.416802
# 0         0.637623  0.406564
# 0         0.637145  0.405953

# %% [markdown]
# # Regresion

# %%
import statsmodels.api as sm

features = ['intercept', 'var_porc_demanda_interna_avg3_std', 'flg_feia_avg3_std',
            'exp_PBI_avg3_std']

# Fit and summarize OLS model
mod = sm.OLS(X_train[target], 
             X_train[features])

res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Venta_zona_2   R-squared:                       0.311
# Model:                            OLS   Adj. R-squared:                  0.259
# Method:                 Least Squares   F-statistic:                     6.013
# Date:                Mon, 25 Jul 2022   Prob (F-statistic):            0.00176
# Time:                        07:53:45   Log-Likelihood:                -182.43
# No. Observations:                  44   AIC:                             372.9
# Df Residuals:                      40   BIC:                             380.0
# Df Model:                           3
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# intercept                            44.0168      2.418     18.205      0.000      39.130      48.903
# var_porc_demanda_interna_avg3_std     9.1532      2.610      3.506      0.001       3.877      14.429
# flg_feia_avg3_std                     5.0141      2.443      2.053      0.047       0.077       9.951
# exp_PBI_avg3_std                      7.1417      2.598      2.748      0.009       1.890      12.393
# ==============================================================================
# Omnibus:                        1.494   Durbin-Watson:                   0.597
# Prob(Omnibus):                  0.474   Jarque-Bera (JB):                1.446
# Skew:                           0.351   Prob(JB):                        0.485
# Kurtosis:                       2.456   Cond. No.                         1.55
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import seaborn as sn
import matplotlib.pyplot as plt

sn.heatmap(X_train[features].corr(), annot=True)
plt.show()

# %%
data_res['macro_pred'] = 44.0168 +\
                         9.1532*data_res.var_porc_demanda_interna_avg3_std +\
                         5.0141*data_res.flg_feia_avg3_std +\
                         7.1417*data_res.exp_PBI_avg3_std

data = data_res.copy().dropna()
X_train = data[:-test_size].dropna()
X_test  = data[-test_size:].dropna()

# %%
#target + '_lag3_avg3'
ensemble = ['venta_predicted', 'macro_pred']

# 2,1,1 ARIMA Model
model_ff = ARIMA(endog = X_train[target], 
                 exog = X_train[ensemble],  
              order=(0,1,3))

model_fit_ff = model_ff.fit()
print(model_fit_ff.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Venta_zona_2   No. Observations:                   43
# Model:                 ARIMA(0, 1, 3)   Log Likelihood                -156.913
# Method:                       css-mle   S.D. of innovations              8.982
# Date:                Mon, 25 Jul 2022   AIC                            327.826
# Time:                        07:53:53   BIC                            340.155
# Sample:                             1   HQIC                           332.373
#
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -3.8318      3.066     -1.250      0.219      -9.841       2.177
# venta_predicted         -0.0667      0.077     -0.866      0.392      -0.218       0.084
# macro_pred               0.1814      0.136      1.336      0.190      -0.085       0.447
# ma.L1.D.Venta_zona_2    -0.2815      0.170     -1.653      0.107      -0.615       0.052
# ma.L2.D.Venta_zona_2    -0.4959      0.206     -2.405      0.021      -0.900      -0.092
# ma.L3.D.Venta_zona_2    -0.2226      0.156     -1.430      0.161      -0.527       0.082
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            1.0000           -0.0000j            1.0000           -0.0000
# MA.2           -1.6141           -1.3740j            2.1197           -0.3878
# MA.3           -1.6141           +1.3740j            2.1197            0.3878
# -----------------------------------------------------------------------------

# %%
import pickle
pickle.dump(model_fit_ff, open("./var_jmz2.ml", 'wb'))

# %%
fc, se, conf  = model_fit_ff.forecast(test_size, 
                                      exog = X_test[['venta_predicted', 'macro_pred']], alpha=0.05)

model_res = model_fit_ff.predict(start = X_train.index[2], 
                                 end = X_train.index[-1], dynamic=False, typ = 'levels')

data_res = data.copy()
data_res['venta_predicted_final'] = model_res
data_res.iloc[-test_size:]['venta_predicted_final'] = fc

sns.lineplot(data = data_res[[target, 'venta_predicted_final']])

# %%
data_res[[target, 'venta_predicted', 'macro_pred', 'venta_predicted_final']]

# %%
mod = sm.OLS(X_train[target], X_train[['venta_predicted', 'macro_pred', 'intercept']])
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Venta_zona_2   R-squared:                       0.774
# Model:                            OLS   Adj. R-squared:                  0.763
# Method:                 Least Squares   F-statistic:                     70.03
# Date:                Mon, 25 Jul 2022   Prob (F-statistic):           5.98e-14
# Time:                        07:46:31   Log-Likelihood:                -157.94
# No. Observations:                  44   AIC:                             321.9
# Df Residuals:                      41   BIC:                             327.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# venta_predicted     0.8688      0.095      9.153      0.000       0.677       1.061
# macro_pred          0.3539      0.151      2.346      0.024       0.049       0.659
# intercept          -9.7806      6.132     -1.595      0.118     -22.164       2.603
# ==============================================================================
# Omnibus:                        0.941   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.625   Jarque-Bera (JB):                1.003
# Skew:                           0.283   Prob(JB):                        0.606
# Kurtosis:                       2.524   Cond. No.                         289.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
data_res['venta_predicted_final'] = 0.1938*data_res.venta_predicted + 0.9125*data_res.macro_pred - 6.1913


data = data_res.copy().dropna()
X_train = data[:-test_size].dropna()
X_test  = data[-test_size:].dropna()

# %%
X_train[['venta_predicted_final', target]].corr()**2
# Out:
#                        venta_predicted_final  Venta_zona_1
# venta_predicted_final               1.000000      0.250031
# Venta_zona_1                        0.250031      1.000000

# %%
data[['venta_predicted',
      'venta_predicted_final', target]].to_csv('results_zona1.csv', index=0)

# %%
data[['venta_predicted',
      'venta_predicted_final', target]]
# Out:
#          venta_predicted  venta_predicted_final  Venta_zona_2
# codmes
# ago-18         14.660557              43.414043            28
# sept-18        29.656052              38.716882            29
# oct-18         28.673498              45.145330            21
# nov-18         20.083870              34.962663            38
# dic-18         36.783986              38.636436            29
# ene-19         27.607873              37.280093            21
# feb-19         21.257489              35.569608            38
# mar-19         38.047287              38.467255            33
# abr-19         32.282695              28.900851            41
# may-19         38.154294              30.046992            34
# jun-19         32.730157              37.002450            27
# jul-19         28.249673              35.793068            24
# ago-19         28.478326              43.746721            33
# sept-19        36.857043              37.246057            34
# oct-19         36.568921              37.450789            34
# nov-19         35.735340              36.998249            35
# dic-19         36.870185              36.347229            41
# ene-20         41.657300              43.968113            50
# feb-20         47.814218              36.597712            34
# mar-20         34.362765              33.412949            19
# abr-20         25.712662              25.237183             5
# may-20         20.071433              24.657079            13
# jun-20         29.827480              25.447834            26
# jul-20         39.129790              28.938938            55
# ago-20         57.076321              28.951870            45
# sept-20        43.494405              38.186844            55
# oct-20         50.109604              38.862939            55
# nov-20         50.522487              53.659922            46
# dic-20         43.703642              46.241654            54
# ene-21         52.264874              59.761867            61
# feb-21         57.990675              56.451612            60
# mar-21         56.176124              61.092732            49
# abr-21         48.788868              46.091077            38
# may-21         43.912253              46.600083            50
# jun-21         56.622760              46.124000            53
# jul-21         58.578301              58.329288            61
# ago-21         63.266208              61.289996            72
# sept-21        70.545002              70.968218            65
# oct-21         63.753496              61.777953            73
# nov-21         70.854872              63.084510            90
# dic-21         83.961927              53.042639            80
# ene-22         74.330748              47.545747            64
# feb-22         64.366118              42.483427            60
# mar-22         67.037235              39.921932            68
# abr-22         76.471095              40.507875            47
# may-22         82.731245              41.509586            52

# %%
X_test[features]
# Out:
#         Venta_zona_1_lag3_avg3
# codmes
# abr-22               63.000000
# may-22               55.333333

# %% [markdown]
# # Implementación

# %%
data[[target + '_lag2_avg3', 'var_porc_demanda_interna_avg3_std', 'flg_feia_avg3_std', 'exp_PBI_avg3_std']]
# Out:
#          Venta_zona_2_lag2_avg3  var_porc_demanda_interna_avg3_std  \
# codmes
# ago-18                26.666667                           0.208986
# sept-18               19.333333                           0.216709
# oct-18                20.666667                           0.028213
# nov-18                23.666667                          -0.073580
# dic-18                26.000000                          -0.021225
# ene-19                29.333333                           0.037163
# feb-19                29.333333                          -0.004553
# mar-19                29.333333                          -0.031474
# abr-19                29.333333                          -0.101441
# may-19                30.666667                          -0.116184
# jun-19                37.333333                          -0.122796
# jul-19                36.000000                          -0.163631
# ago-19                34.000000                          -0.134711
# sept-19               28.333333                          -0.110748
# oct-19                28.000000                          -0.000912
# nov-19                30.333333                           0.050751
# dic-19                33.666667                           0.040840
# ene-20                34.333333                          -0.028669
# feb-20                36.666667                          -0.065148
# mar-20                42.000000                          -0.142199
# abr-20                41.666667                          -0.033764
# may-20                34.333333                          -0.019507
# jun-20                19.333333                          -0.442166
# jul-20                12.333333                          -1.441173
# ago-20                14.666667                          -2.280691
# sept-20               31.333333                          -2.281200
# oct-20                42.000000                          -1.718800
# nov-20                51.666667                          -1.220829
# dic-20                51.666667                          -1.001280
# ene-21                52.000000                          -0.845242
# feb-21                51.666667                          -0.582204
# mar-21                53.666667                          -0.220346
# abr-21                58.333333                          -0.109162
# may-21                56.666667                          -0.145364
# jun-21                49.000000                           0.273370
# jul-21                45.666667                           1.610666
# ago-21                47.000000                           2.758688
# sept-21               54.666667                           2.893412
# oct-21                62.000000                           2.029308
# nov-21                66.000000                           1.228740
# dic-21                70.000000                           0.829104
# ene-22                76.000000                           0.622501
# feb-22                81.000000                           0.341979
# mar-22                78.000000                           0.036230
# abr-22                68.000000                          -0.104648
# may-22                64.000000                          -0.098516
#
#          flg_feia_avg3_std  exp_PBI_avg3_std
# codmes
# ago-18            1.695627         -0.445745
# sept-18          -0.037681         -0.405430
# oct-18            1.695627         -0.365115
# nov-18           -0.037681         -0.324799
# dic-18           -0.037681         -0.324799
# ene-19           -0.037681         -0.334878
# feb-19           -0.037681         -0.355036
# mar-19           -0.037681         -0.375193
# abr-19           -1.770988         -0.365115
# may-19           -1.770988         -0.344957
# jun-19           -0.037681         -0.324799
# jul-19           -0.037681         -0.324799
# ago-19            1.695627         -0.365115
# sept-19          -0.037681         -0.425587
# oct-19           -0.037681         -0.526375
# nov-19           -0.037681         -0.637241
# dic-19           -0.037681         -0.758187
# ene-20            1.695627         -0.858974
# feb-20           -0.037681         -0.909368
# mar-20           -0.037681         -0.899289
# abr-20           -1.770988         -0.818659
# may-20           -1.770988         -0.758187
# jun-20           -1.770988         -0.385272
# jul-20           -0.037681         -0.062751
# ago-20           -0.037681          0.481502
# sept-20           1.695627          1.086229
# oct-20           -0.037681          1.489380
# nov-20            1.695627          1.892531
# dic-20           -0.037681          1.892531
# ene-21            1.695627          2.295682
# feb-21           -0.037681          2.497257
# mar-21           -0.037681          2.799620
# abr-21           -1.770988          1.791743
# may-21           -0.037681          0.844338
# jun-21           -0.037681         -0.143382
# jul-21           -0.037681         -0.042594
# ago-21           -1.770988          0.017879
# sept-21          -0.037681         -0.103066
# oct-21           -0.037681         -0.203854
# nov-21            1.695627         -0.405430
# dic-21           -0.037681         -0.607005
# ene-22           -0.037681         -0.899289
# feb-22           -0.037681         -1.020235
# mar-22           -0.037681         -1.100865
# abr-22           -0.037681         -1.110944
# may-22           -0.037681         -1.151259

# %%
input = pd.DataFrame({'Venta_zona_2_lag2_avg3' : [76, 84, 88, 89, 91, 93],
                      'var_porc_demanda_interna_avg3_std' : [-0.098516	]*6,
                      'flg_feia_avg3_std' : [-0.037681]*6,
                      'exp_PBI_avg3_std' : [-1.151259]*6
                      },
                      index = ['jun-22', 'jul-22', 'ago-22', 'sept-22', 'oct-22', 'nov-22'])

# %%
fc_pred, se, conf  = model_fit.forecast(6, exog = input['Venta_zona_2_lag2_avg3'], alpha=0.05)
input['venta_predicted'] = fc_pred
fc_pred
# Out:
# array([68.97088137, 66.22324846, 63.24923195, 61.14711388, 58.86297887,
#        55.85675146])

# %%
input['macro_pred'] = 44.0168 +\
                         9.1532*input.var_porc_demanda_interna_avg3_std +\
                         5.0141*input.flg_feia_avg3_std +\
                         7.1417*input.exp_PBI_avg3_std


                         
#input['venta_predicted_final'] = 0.1938*input.venta_predicted + 0.9125*input.macro_pred - 6.1913

# %%
fc_pred, se, conf  = model_fit_ff.forecast(6, exog = input[['venta_predicted', 'macro_pred']], alpha=0.05)
input['venta_predicted_final'] = fc_pred
input['venta_predicted_final']
fc_pred
# Out:
# array([67.92606985, 64.54787596, 61.81448138, 60.2010041 , 58.73982341,
#        57.47908542])
